# %%
import sys
import json
from pathlib import Path
from dotenv import load_dotenv

ROOT = Path.cwd()
sys.path.insert(0, str(ROOT))
load_dotenv(ROOT / ".env")

TRAIN_JSONL = ROOT / "train.jsonl"
MAX_LINES = 1090
MAX_REQUIREMENTS = 2000
DOC_ID = "train_jsonl"
CHECKPOINT_PATH = ROOT / "requirements_checkpoint_embed_tier.json"
EMBEDDINGS_CACHE_DIR = ROOT / "data"
LOAD_CHECKPOINT = True

# %%
# from pathlib import Path
# if "CHECKPOINT_PATH" not in globals():
#     CHECKPOINT_PATH = Path.cwd() / "requirements_checkpoint_embed_tier.json"
# if "DOC_ID" not in globals():
#     DOC_ID = "train_jsonl"

# checkpoint = {
#     "requirements_with_tiers": [{"entry": e.model_dump(), "tier": t} for e, t in requirements_with_tiers],
#     "trace_pairs": [list(p) for p in trace_pairs],
#     "doc_id": DOC_ID,
# }
# if embeddings and len(embeddings) == len(requirements_with_tiers):
#     checkpoint["embeddings"] = embeddings
# CHECKPOINT_PATH.write_text(json.dumps(checkpoint, indent=2), encoding="utf-8")
# print(f"Saved checkpoint to {CHECKPOINT_PATH} ({len(requirements_with_tiers)} requirements, {len(trace_pairs)} pairs, embeddings={'yes' if checkpoint.get('embeddings') else 'no'}).")

# %%
from src.schema import Entry

if LOAD_CHECKPOINT and CHECKPOINT_PATH.exists():
    data = json.loads(CHECKPOINT_PATH.read_text(encoding="utf-8"))
    requirements_with_tiers = [(Entry(**d["entry"]), d["tier"]) for d in data["requirements_with_tiers"]]
    trace_pairs = [tuple(p) for p in data["trace_pairs"]]
    requirements = [e for e, _ in requirements_with_tiers]
    DOC_ID = data.get("doc_id", DOC_ID)
    emb = data.get("embeddings") or []
    embeddings = emb if len(emb) == len(requirements_with_tiers) else None
    print(f"Loaded checkpoint: {len(requirements_with_tiers)} requirements, {len(trace_pairs)} trace pairs, embeddings={'yes' if embeddings else 'no'}.")
else:
    requirements = requirements_with_tiers = trace_pairs = embeddings = None
# Out:
# Loaded checkpoint: 2000 requirements, 1293 trace pairs, embeddings=yes.

# %%
from src.schema import Entry

def is_req_value(v):
    if v is True: return True
    if v is False or v is None: return False
    return str(v).strip().lower() in ("true", "yes", "1", "requirement")

if requirements is None:
    entries_all = []
    lines_read = 0
    with open(TRAIN_JSONL, "r", encoding="utf-8") as f:
        for line in f:
            if lines_read >= MAX_LINES: break
            line = line.strip()
            if not line: continue
            try:
                row = json.loads(line)
                out = row.get("output") or {}
                for e in out.get("entries") or []:
                    if not is_req_value(e.get("is_requirement")): continue
                    entries_all.append(Entry(
                        doc_title=e.get("doc_title") or "",
                        page_number=int(e.get("page_number", 0)),
                        section_title=e.get("section_title") or "",
                        text=(e.get("text") or "").strip(),
                        is_requirement="true",
                    ))
                    if len(entries_all) >= MAX_REQUIREMENTS: break
            except (json.JSONDecodeError, KeyError, TypeError):
                continue
            lines_read += 1
            if len(entries_all) >= MAX_REQUIREMENTS: break
    requirements = entries_all
print(f"Loaded {len(requirements)} requirements.")
# Out:
# Loaded 2000 requirements.

# %%
from src.titan_embeddings import get_embeddings_for_entries, embeddings_cache_path

embed_cache = embeddings_cache_path(ROOT, DOC_ID)
if embeddings is None or len(embeddings) != len(requirements):
    embeddings = get_embeddings_for_entries(requirements, embed_cache, DOC_ID, dimensions=1024)
else:
    print(f"Using {len(embeddings)} embeddings from checkpoint.")
# Out:
# Using 2000 embeddings from checkpoint.

# %%
from src.tier_by_similarity import assign_tiers_by_similarity_with_fallback

if requirements_with_tiers is None:
    requirements_with_tiers = assign_tiers_by_similarity_with_fallback(
        requirements, embeddings, sample_size=60
    )
else:
    print("Using tiers from checkpoint.")
for e, tier in requirements_with_tiers[:10]:
    print(f"  [{tier}] {e.text[:60]}...")
print(f"... total {len(requirements_with_tiers)}")
# Out:
# Using tiers from checkpoint.
#   [component] Control RCS pressure and accommodate volume changes...
#   [component] The pressurizer design controls pressure and accommodates co...
#   [component] The RCP is a vertical, centrifugal type pump. The pump is de...
#   [component] Two pressurizer safety valves protect the reactor coolant pr...
#   [component] The system level top gates and associated success criteria t...
#   [system] The basis for common cause component groupings (CCCGs) and c...
#   [system] The basis for test and maintenance activities that are inclu...
#   [component] The RCP is a vertical, centrifugal type pump. The pump is de...
#   [component] Two pressurizer safety valves protect the reactor coolant pr...
#   [component] The RCP has provisions to prevent motor damage due to overhe...
# ... total 2000

# %%
from src.nova_traces import get_trace_pairs_from_nova_with_fallback

trace_pairs = get_trace_pairs_from_nova_with_fallback(requirements_with_tiers, batch_size=12)
print(f"Nova: {len(trace_pairs)} pairs.")
# Out:
# Nova: 1450 pairs.

# %%
import importlib
import src.neo4j_loader
importlib.reload(src.neo4j_loader)
from src.neo4j_loader import (
    get_driver,
    load_tiered_requirements_into_neo4j,
    requirement_full_id,
    create_trace_edges,
    tier_based_trace_pairs,
    filter_trace_pairs_to_adjacent_tiers,
)

driver = get_driver()
print("Loading requirement nodes into Neo4j...")
n = load_tiered_requirements_into_neo4j(
    requirements_with_tiers, driver=driver, document_id=DOC_ID, embeddings=embeddings if embeddings else None
)
print(f"Loaded {n} requirement nodes.")

full_ids = [requirement_full_id(DOC_ID, e, i) for i, (e, _) in enumerate(requirements_with_tiers)]
tier_pairs = tier_based_trace_pairs(requirements_with_tiers)
combined = list({p for p in trace_pairs + tier_pairs})
all_pairs = filter_trace_pairs_to_adjacent_tiers(requirements_with_tiers, combined)
print(f"Creating TRACES_TO edges ({len(all_pairs)} pairs, batched)...")

try:
    from tqdm.auto import tqdm
    pbar_ref = [None]
    def _on_batch(batch_num, total_batches, _):
        if pbar_ref[0] is None:
            pbar_ref[0] = tqdm(total=total_batches, desc="Trace edges", unit="batch")
        pbar_ref[0].update(1)
    edges = create_trace_edges(full_ids, all_pairs, driver=driver, progress_callback=_on_batch)
    if pbar_ref[0] is not None:
        pbar_ref[0].close()
except ImportError:
    def _on_batch(batch_num, total_batches, edges_this_batch):
        print(f"  Batch {batch_num}/{total_batches} ({edges_this_batch} edges)")
    edges = create_trace_edges(full_ids, all_pairs, driver=driver, progress_callback=_on_batch)

print(f"Created {edges} TRACES_TO edges.")
driver.close()
# Out:
# Loading requirement nodes into Neo4j...
# Loaded 2000 requirement nodes.
# Creating TRACES_TO edges (970956 pairs, batched)...
# Trace edges:   0%|          | 0/486 [00:00<?, ?batch/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File c:\Users\eric_ppds\Documents\New folder\src\neo4j_loader.py:145, in create_trace_edges(requirement_full_ids, pairs, driver, batch_size, progress_callback)
#     143     return len(param) * 2
# --> 145 total += session.execute_write(_run)
#     146 if progress_callback:
#
# File c:\Users\eric_ppds\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\work\session.py:720, in Session.execute_write(self, transaction_function, *args, **kwargs)
#     676 """
#     677 Execute a unit of work in a managed write transaction.
#     678
#    (...)
#     718 .. versionadded:: 5.0
#     719 """  # noqa: E501 example code isn't too long
# --> 720 return self._run_transaction(
#     721     WRITE_ACCESS,
#     722     TelemetryAPI.TX_FUNC,
#     723     transaction_function,
#     724     args,
#     725     kwargs,
#     726 )
#
# File c:\Users\eric_ppds\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\work\session.py:543, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#     542 try:
# --> 543     result = transaction_function(tx, *args, **kwargs)
#     544 except asyncio.CancelledError:
#     545     # if cancellation callback has not been called yet:
#
# File c:\Users\eric_ppds\Documents\New folder\src\neo4j_loader.py:137, in create_trace_edges.<locals>._run(tx, param)
#     136 def _run(tx, param=batch_param):
# --> 137     result = tx.run(
#     138         "UNWIND $pairs AS p MATCH (a:Requirement {id: p.a_id}), (b:Requirement {id: p.b_id}) "
#     139         "MERGE (a)-[:TRACES_TO]->(b) MERGE (b)-[:TRACES_TO]->(a)",
#     140         pairs=param,
#     141     )
#     142     result.consume()
#
# File c:\Users\eric_ppds\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\work\transaction.py:201, in TransactionBase.run(self, query, parameters, **kwparameters)
#     200 parameters = dict(parameters or {}, **kwparameters)
# --> 201 result._tx_ready_run(query, parameters)
#     203 return result
#
# File c:\Users\eric_ppds\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\work\result.py:178, in Result._tx_ready_run(self, query, parameters)
#     174 def _tx_ready_run(self, query, parameters):
#     175     # BEGIN+RUN does not carry any extra on the RUN message.
#     176     # BEGIN {extra}
#     177     # RUN "query" {parameters} {extra}
# --> 178     self._run(query, parameters, None, None, None, None, None, None)
#
# File c:\Users\eric_ppds\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\work\result.py:237, in Result._run(self, query, parameters, db, imp_user, access_mode, bookmarks, notifications_min_severity, notifications_disabled_classifications)
#     236 self._connection.send_all()
# --> 237 self._attach()
#
# File c:\Users\eric_ppds\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\work\result.py:439, in Result._attach(self)
#     438 while self._attached is False:
# --> 439     self._connection.fetch_message()
#
# File c:\Users\eric_ppds\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\io\_common.py:193, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#     192 try:
# --> 193     func(*args, **kwargs)
#     194 except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#
# File c:\Users\eric_ppds\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\io\_bolt.py:864, in Bolt.fetch_message(self)
#     863 # Receive exactly one message
# --> 864 tag, fields = self.inbox.pop(
#     865     hydration_hooks=self.responses[0].hydration_hooks
#     866 )
#     867 res = self._process_message(tag, fields)
#
# File c:\Users\eric_ppds\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\io\_common.py:77, in Inbox.pop(self, hydration_hooks)
#      76 def pop(self, hydration_hooks):
# ---> 77     self._buffer_one_chunk()
#      78     try:
#
# File c:\Users\eric_ppds\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\io\_common.py:54, in Inbox._buffer_one_chunk(self)
#      52 while chunk_size == 0:
#      53     # Determine the chunk size and skip noop
# ---> 54     receive_into_buffer(self._socket, self._buffer, 2)
#      55     chunk_size = self._buffer.pop_u16()
#
# File c:\Users\eric_ppds\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\io\_common.py:340, in receive_into_buffer(sock, buffer, n_bytes)
#     339 while buffer.used < end:
# --> 340     n = sock.recv_into(
#     341         view[buffer.used : end], end - buffer.used
#     342     )
#     343     if n == 0:
#
# File c:\Users\eric_ppds\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_async_compat\network\_bolt_socket.py:461, in BoltSocketBase.recv_into(self, buffer, nbytes)
#     460 def recv_into(self, buffer, nbytes):
# --> 461     return self._wait_for_read(self._socket.recv_into, buffer, nbytes)
#
# File c:\Users\eric_ppds\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_async_compat\network\_bolt_socket.py:390, in BoltSocketBase._wait_for_read(self, func, *args, **kwargs)
#     389 def _wait_for_read(self, func, *args, **kwargs):
# --> 390     return self._wait_for_io(
#     391         "read",
#     392         self._read_timeout,
#     393         self._read_deadline,
#     394         func,
#     395         *args,
#     396         **kwargs,
#     397     )
#
# File c:\Users\eric_ppds\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_async_compat\network\_bolt_socket.py:427, in BoltSocketBase._wait_for_io(self, name, timeout, deadline, func, *args, **kwargs)
#     426 try:
# --> 427     return func(*args, **kwargs)
#     428 except TimeoutError as e:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# BufferError                               Traceback (most recent call last)
# File c:\Users\eric_ppds\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\work\transaction.py:248, in TransactionBase._rollback(self)
#     247         self._connection.send_all()
# --> 248         self._connection.fetch_all()
#     249 except asyncio.CancelledError:
#
# File c:\Users\eric_ppds\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\io\_bolt.py:882, in Bolt.fetch_all(self)
#     881 while not response.complete:
# --> 882     detail_delta, summary_delta = self.fetch_message()
#     883     detail_count += detail_delta
#
# File c:\Users\eric_ppds\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\io\_bolt.py:864, in Bolt.fetch_message(self)
#     863 # Receive exactly one message
# --> 864 tag, fields = self.inbox.pop(
#     865     hydration_hooks=self.responses[0].hydration_hooks
#     866 )
#     867 res = self._process_message(tag, fields)
#
# File c:\Users\eric_ppds\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\io\_common.py:77, in Inbox.pop(self, hydration_hooks)
#      76 def pop(self, hydration_hooks):
# ---> 77     self._buffer_one_chunk()
#      78     try:
#
# File c:\Users\eric_ppds\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\io\_common.py:59, in Inbox._buffer_one_chunk(self)
#      57         log.debug("[#%04X]  S: <NOOP>", self._local_port)
# ---> 59 receive_into_buffer(
#      60     self._socket, self._buffer, chunk_size + 2
#      61 )
#      62 chunk_size = self._buffer.pop_u16()
#
# File c:\Users\eric_ppds\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\io\_common.py:337, in receive_into_buffer(sock, buffer, n_bytes)
#     336 if end > len(buffer.data):
# --> 337     buffer.data += bytearray(end - len(buffer.data))
#     338 with memoryview(buffer.data) as view:
#
# BufferError: Existing exports of data: object cannot be re-sized
#
# During handling of the above exception, another exception occurred:
#
# BufferError                               Traceback (most recent call last)
# Cell In[17], line 33
#      31         pbar_ref[0] = tqdm(total=total_batches, desc="Trace edges", unit="batch")
#      32     pbar_ref[0].update(1)
# ---> 33 edges = create_trace_edges(full_ids, all_pairs, driver=driver, progress_callback=_on_batch)
#      34 if pbar_ref[0] is not None:
#      35     pbar_ref[0].close()
#
# File c:\Users\eric_ppds\Documents\New folder\src\neo4j_loader.py:131, in create_trace_edges(requirement_full_ids, pairs, driver, batch_size, progress_callback)
#     129 total_batches = (len(valid) + batch_size - 1) // batch_size
#     130 total = 0
# --> 131 with driver.session() as session:
#     132     for batch_idx, start in enumerate(range(0, len(valid), batch_size)):
#     133         batch = valid[start : start + batch_size]
#
# File c:\Users\eric_ppds\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\work\session.py:120, in Session.__exit__(self, exception_type, exception_value, traceback)
#     118         return
#     119     self._state_failed = True
# --> 120 self.close()
#
# File c:\Users\eric_ppds\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\work\session.py:208, in Session.close(self)
#     205 if self._transaction:
#     206     if self._transaction._closed() is False:
#     207         # roll back the transaction if it is not closed
# --> 208         self._transaction._rollback()
#     209     self._transaction = None
#     211 try:
#
# File c:\Users\eric_ppds\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\work\transaction.py:254, in TransactionBase._rollback(self)
#     252 finally:
#     253     self._closed_flag = True
# --> 254     Util.callback(self._on_closed)
#
# File c:\Users\eric_ppds\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_async_compat\util.py:105, in Util.callback(cb, *args, **kwargs)
#     102 @staticmethod
#     103 def callback(cb, *args, **kwargs):
#     104     if callable(cb):
# --> 105         return cb(*args, **kwargs)
#     106     return None
#
# File c:\Users\eric_ppds\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\work\session.py:378, in Session._transaction_closed_handler(self)
#     376 self._update_bookmark(self._transaction._bookmark)
#     377 self._transaction = None
# --> 378 self._disconnect()
#
# File c:\Users\eric_ppds\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\work\session.py:135, in Session._disconnect(self, sync)
#     133 def _disconnect(self, sync=False):
#     134     try:
# --> 135         return super()._disconnect(sync=sync)
#     136     except asyncio.CancelledError:
#     137         self._handle_cancellation(message="_disconnect")
#
# File c:\Users\eric_ppds\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\work\workspace.py:282, in Workspace._disconnect(self, sync)
#     280         pass
#     281 if self._connection:
# --> 282     self._pool.release(self._connection)
#     283     self._connection = None
#     284 self._connection_access_mode = None
#
# File c:\Users\eric_ppds\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\io\_pool.py:495, in IOPool.release(self, *connections)
#     489 try:
#     490     log.debug(
#     491         "[#%04X]  _: <POOL> release unclean connection %s",
#     492         connection.local_port,
#     493         connection.connection_id,
#     494     )
# --> 495     connection.reset()
#     496 except (Neo4jError, DriverError, BoltError) as exc:
#     497     log.debug(
#     498         "[#%04X]  _: <POOL> failed to reset connection "
#     499         "on release: %r",
#     500         connection.local_port,
#     501         exc,
#     502     )
#
# File c:\Users\eric_ppds\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\io\_bolt6.py:495, in Bolt6x0.reset(self, dehydration_hooks, hydration_hooks)
#     491 self._append(
#     492     b"\x0f", response=response, dehydration_hooks=dehydration_hooks
#     493 )
#     494 self.send_all()
# --> 495 self.fetch_all()
#
# File c:\Users\eric_ppds\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\io\_bolt.py:882, in Bolt.fetch_all(self)
#     880 response = self.responses[0]
#     881 while not response.complete:
# --> 882     detail_delta, summary_delta = self.fetch_message()
#     883     detail_count += detail_delta
#     884     summary_count += summary_delta
#
# File c:\Users\eric_ppds\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\io\_bolt.py:864, in Bolt.fetch_message(self)
#     861     return 0, 0
#     863 # Receive exactly one message
# --> 864 tag, fields = self.inbox.pop(
#     865     hydration_hooks=self.responses[0].hydration_hooks
#     866 )
#     867 res = self._process_message(tag, fields)
#     868 self.idle_since = monotonic()
#
# File c:\Users\eric_ppds\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\io\_common.py:77, in Inbox.pop(self, hydration_hooks)
#      76 def pop(self, hydration_hooks):
# ---> 77     self._buffer_one_chunk()
#      78     try:
#      79         size, tag = self._unpacker.unpack_structure_header()
#
# File c:\Users\eric_ppds\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\io\_common.py:59, in Inbox._buffer_one_chunk(self)
#      56     if chunk_size == 0:
#      57         log.debug("[#%04X]  S: <NOOP>", self._local_port)
# ---> 59 receive_into_buffer(
#      60     self._socket, self._buffer, chunk_size + 2
#      61 )
#      62 chunk_size = self._buffer.pop_u16()
#      64 if chunk_size == 0:
#      65     # chunk_size was the end marker for the message
#
# File c:\Users\eric_ppds\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\io\_common.py:337, in receive_into_buffer(sock, buffer, n_bytes)
#     335 end = buffer.used + n_bytes
#     336 if end > len(buffer.data):
# --> 337     buffer.data += bytearray(end - len(buffer.data))
#     338 with memoryview(buffer.data) as view:
#     339     while buffer.used < end:
#
# BufferError: Existing exports of data: object cannot be re-sized
