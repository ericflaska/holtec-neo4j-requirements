# %%
import sys
import json
from pathlib import Path
from dotenv import load_dotenv

ROOT = Path.cwd()
sys.path.insert(0, str(ROOT))
load_dotenv(ROOT / ".env")

TRAIN_JSONL = ROOT / "train.jsonl"
MAX_LINES = 1090
MAX_REQUIREMENTS = 2000
DOC_ID = "train_jsonl"
CHECKPOINT_PATH = ROOT / "requirements_checkpoint_embed_tier.json"
EMBEDDINGS_CACHE_DIR = ROOT / "data"
LOAD_CHECKPOINT = True

# %%
from src.schema import Entry

if LOAD_CHECKPOINT and CHECKPOINT_PATH.exists():
    data = json.loads(CHECKPOINT_PATH.read_text(encoding="utf-8"))
    requirements_with_tiers = [(Entry(**d["entry"]), d["tier"]) for d in data["requirements_with_tiers"]]
    trace_pairs = [tuple(p) for p in data["trace_pairs"]]
    requirements = [e for e, _ in requirements_with_tiers]
    DOC_ID = data.get("doc_id", DOC_ID)
    emb = data.get("embeddings") or []
    embeddings = emb if len(emb) == len(requirements_with_tiers) else None
    print(f"Loaded checkpoint: {len(requirements_with_tiers)} requirements, {len(trace_pairs)} trace pairs, embeddings={'yes' if embeddings else 'no'}.")
else:
    requirements = requirements_with_tiers = trace_pairs = embeddings = None
# Out:
# Loaded checkpoint: 2000 requirements, 1338 trace pairs, embeddings=yes.

# %%
from src.schema import Entry

def is_req_value(v):
    if v is True: return True
    if v is False or v is None: return False
    return str(v).strip().lower() in ("true", "yes", "1", "requirement")

if requirements is None:
    entries_all = []
    lines_read = 0
    with open(TRAIN_JSONL, "r", encoding="utf-8") as f:
        for line in f:
            if lines_read >= MAX_LINES: break
            line = line.strip()
            if not line: continue
            try:
                row = json.loads(line)
                out = row.get("output") or {}
                for e in out.get("entries") or []:
                    if not is_req_value(e.get("is_requirement")): continue
                    entries_all.append(Entry(
                        doc_title=e.get("doc_title") or "",
                        page_number=int(e.get("page_number", 0)),
                        section_title=e.get("section_title") or "",
                        text=(e.get("text") or "").strip(),
                        is_requirement="true",
                    ))
                    if len(entries_all) >= MAX_REQUIREMENTS: break
            except (json.JSONDecodeError, KeyError, TypeError):
                continue
            lines_read += 1
            if len(entries_all) >= MAX_REQUIREMENTS: break
    requirements = entries_all
print(f"Loaded {len(requirements)} requirements.")
# Out:
# Loaded 2000 requirements.

# %% [markdown]
# **Embed first (before tiers):** Compute Titan embeddings for all requirements. Same cache as main notebook (by doc_id + count); tiers are assigned later by cosine similarity to exemplars.

# %%
from src.titan_embeddings import get_embeddings_for_entries, embeddings_cache_path

embed_cache = embeddings_cache_path(ROOT, DOC_ID)
if embeddings is None or len(embeddings) != len(requirements):
    embeddings = get_embeddings_for_entries(requirements, embed_cache, DOC_ID, dimensions=1024)
else:
    print(f"Using {len(embeddings)} embeddings from checkpoint.")
# Out:
# Computed 2000 embeddings (dim=1024), saved to c:\Users\eric_ppds\Documents\New folder\data\embeddings_train_jsonl.json.

# %% [markdown]
# **Tier by cosine similarity:** Nova labels a random sample (e.g. 60) as exemplars per tier. For each requirement, assign the tier whose exemplar centroid has highest cosine similarity to its embedding.

# %%
from src.tier_by_similarity import assign_tiers_by_similarity_with_fallback

if requirements_with_tiers is None:
    requirements_with_tiers = assign_tiers_by_similarity_with_fallback(
        requirements, embeddings, sample_size=60
    )
else:
    print("Using tiers from checkpoint.")
for e, tier in requirements_with_tiers[:10]:
    print(f"  [{tier}] {e.text[:60]}...")
print(f"... total {len(requirements_with_tiers)}")
# Out:
#   [component] Control RCS pressure and accommodate volume changes...
#   [component] The pressurizer design controls pressure and accommodates co...
#   [component] The RCP is a vertical, centrifugal type pump. The pump is de...
#   [component] Two pressurizer safety valves protect the reactor coolant pr...
#   [component] The system level top gates and associated success criteria t...
#   [system] The basis for common cause component groupings (CCCGs) and c...
#   [system] The basis for test and maintenance activities that are inclu...
#   [component] The RCP is a vertical, centrifugal type pump. The pump is de...
#   [component] Two pressurizer safety valves protect the reactor coolant pr...
#   [component] The RCP has provisions to prevent motor damage due to overhe...
# ... total 2000

# %%
from src.nova_traces import get_trace_pairs_from_nova_with_fallback

trace_pairs = get_trace_pairs_from_nova_with_fallback(requirements_with_tiers, batch_size=12)
print(f"Nova: {len(trace_pairs)} pairs.")
# Out:
# Nova: 1338 pairs.

# %%
from src.neo4j_loader import (
    get_driver,
    load_tiered_requirements_into_neo4j,
    requirement_full_id,
    create_trace_edges,
    tier_based_trace_pairs,
    filter_trace_pairs_to_adjacent_tiers,
)

driver = get_driver()
n = load_tiered_requirements_into_neo4j(
    requirements_with_tiers, driver=driver, document_id=DOC_ID, embeddings=embeddings if embeddings else None
)
print(f"Loaded {n} requirement nodes.")

full_ids = [requirement_full_id(DOC_ID, e) for e, _ in requirements_with_tiers]
tier_pairs = tier_based_trace_pairs(requirements_with_tiers)
combined = list({p for p in trace_pairs + tier_pairs})
all_pairs = filter_trace_pairs_to_adjacent_tiers(requirements_with_tiers, combined)
edges = create_trace_edges(full_ids, all_pairs, driver=driver)
print(f"Created {edges} TRACES_TO edges.")
driver.close()

# %% [markdown]
# ### Graph RAG (for later)
#
# **What it is:** Graph RAG uses a knowledge graph (like our Neo4j requirements + TRACES_TO) to improve retrieval for RAG. Instead of only searching flat chunks, you (1) retrieve relevant nodes, (2) walk the graph (e.g. neighbors, multi-hop) to pull in connected context, then (3) send that subgraph + nodes to the LLM. That gives the model both requirement text and *structure* (traceability, tier hierarchy).
#
# **Why it fits here:** Your graph already has Requirement nodes with `tier` and TRACES_TO only between adjacent tiers (plant↔system, system↔component). So you can answer questions like "what systems implement this plant requirement?" or "which component requirements trace to this system?" by starting at a node and following edges, then summarizing with an LLM. You could also do community detection or centrality on the graph to find key requirements before retrieval.
#
# **When you're ready:** Implement a retriever that (a) finds requirements (e.g. by text or id), (b) runs a Cypher or in-memory walk to get k-hop neighbors (optionally filtered by tier), (c) builds a prompt from those nodes + edges, and (d) calls Nova (or another model) for the answer. No code here—just a direction to explore.

# %%
from pathlib import Path
if "CHECKPOINT_PATH" not in globals():
    CHECKPOINT_PATH = Path.cwd() / "requirements_checkpoint_embed_tier.json"
if "DOC_ID" not in globals():
    DOC_ID = "train_jsonl"

checkpoint = {
    "requirements_with_tiers": [{"entry": e.model_dump(), "tier": t} for e, t in requirements_with_tiers],
    "trace_pairs": [list(p) for p in trace_pairs],
    "doc_id": DOC_ID,
}
if embeddings and len(embeddings) == len(requirements_with_tiers):
    checkpoint["embeddings"] = embeddings
CHECKPOINT_PATH.write_text(json.dumps(checkpoint, indent=2), encoding="utf-8")
print(f"Saved checkpoint to {CHECKPOINT_PATH} ({len(requirements_with_tiers)} requirements, {len(trace_pairs)} pairs, embeddings={'yes' if checkpoint.get('embeddings') else 'no'}).")
# Out:
# Saved checkpoint to c:\Users\eric_ppds\Documents\New folder\requirements_checkpoint_embed_tier.json (2000 requirements, 1338 pairs, embeddings=yes).

# %%
# Push requirements + trace edges to Neo4j (run this anytime you want to sync to the graph)
import importlib
import src.neo4j_loader
importlib.reload(src.neo4j_loader)
from src.neo4j_loader import (
    get_driver,
    load_tiered_requirements_into_neo4j,
    requirement_full_id,
    create_trace_edges,
    tier_based_trace_pairs,
    filter_trace_pairs_to_adjacent_tiers,
)

driver = get_driver()
print("Loading requirement nodes into Neo4j...")
n = load_tiered_requirements_into_neo4j(
    requirements_with_tiers, driver=driver, document_id=DOC_ID, embeddings=embeddings if embeddings else None
)
print(f"Loaded {n} requirement nodes.")

full_ids = [requirement_full_id(DOC_ID, e) for e, _ in requirements_with_tiers]
tier_pairs = tier_based_trace_pairs(requirements_with_tiers)
combined = list({p for p in trace_pairs + tier_pairs})
all_pairs = filter_trace_pairs_to_adjacent_tiers(requirements_with_tiers, combined)
print(f"Creating TRACES_TO edges ({len(all_pairs)} pairs, batched)...")

try:
    from tqdm.auto import tqdm
    pbar_ref = [None]
    def _on_batch(batch_num, total_batches, _):
        if pbar_ref[0] is None:
            pbar_ref[0] = tqdm(total=total_batches, desc="Trace edges", unit="batch")
        pbar_ref[0].update(1)
    edges = create_trace_edges(full_ids, all_pairs, driver=driver, progress_callback=_on_batch)
    if pbar_ref[0] is not None:
        pbar_ref[0].close()
except ImportError:
    def _on_batch(batch_num, total_batches, edges_this_batch):
        print(f"  Batch {batch_num}/{total_batches} ({edges_this_batch} edges)")
    edges = create_trace_edges(full_ids, all_pairs, driver=driver, progress_callback=_on_batch)

print(f"Created {edges} TRACES_TO edges.")
driver.close()
# Out:
# Loading requirement nodes into Neo4j...
# Loaded 2000 requirement nodes.
# Creating TRACES_TO edges (970950 pairs, batched)...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 31
#      29         pbar_ref[0] = tqdm(total=total_batches, desc="Trace edges", unit="batch")
#      30     pbar_ref[0].update(1)
# ---> 31 edges = create_trace_edges(full_ids, all_pairs, driver=driver, progress_callback=_on_batch)
#      32 if pbar_ref[0] is not None:
#      33     pbar_ref[0].close()
#
# TypeError: create_trace_edges() got an unexpected keyword argument 'progress_callback'

# %%
import tqdm
